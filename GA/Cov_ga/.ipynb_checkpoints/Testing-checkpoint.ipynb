# %%
from Util import *
import pandas as pd
import tensorflow as tf
import numpy as np

# %%
layer_dict=pd.read_csv('layer_dict.csv', index_col=0)

# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import cv2
import keras
import numpy as np
import random
import time
import warnings
from Util import extractModelArchitect, buildModelByArtchitect, modelReduction, total_lines, calc_coverage

class Cov_GA:
    def __init__(self, model_architecture, seedlist, x):
        #population: list of (model_architecture, hyperparamters seed list)
        assert len(model_architecture) == len(seedlist), 'layer not matching seed length'
        self.P = []
        
        self.source_architect = model_architecture
        self.source_seedlist = seedlist
        self.source_model_coverage = None
        
        if len(x.shape) == 3:
            self.input = x[None,:]
        else: self.input = x
        
        self.fit_hist = []
        self.fail_P = []
        
    # initialzie model architecture list
    def initPopulation(self, n):
        self.n = n
        
#         source_model_architecture = modelReduction(extractModelArchitect(self.source_model))
        
#         layer_names = layer_dict.index.tolist()
#         source_seedlist = []
#         unknown_layer = []
        
#         for layer in source_model_architecture:
#             if layer in layer_names:
#                 seed = np.zeros(layer_dict.loc[layer]['para_num'], dtype=int).tolist()
#                 source_seedlist.append(seed)
#             else:
#                 unknown_layer.append(layer)
        
        
#         for u in unknown_layer: source_model_architecture.remove(u)
#         if unknown_layer: print(f'Layer unknown: {unknown_layer}')
        
        self.P.append((self.source_architect, self.source_seedlist))        
        self.source_model_coverage = calc_coverage(self.source_architect, self.source_seedlist, self.input)
                
        for _ in range(n-1):
            print(f'Initializaing population: {_+1}/{n}')
            #mutate
            mutate_seedlist = []
            for seed in self.source_seedlist:
                noise = np.array([_ for _ in np.random.standard_cauchy(len(seed))], dtype=int)
                mutate_seedlist.append((seed + noise).tolist())
            self.P.append((self.source_architect, mutate_seedlist))

        return 

    # compute fitness scores for populations
    def computeFitness(self):
        Fit = []
        for p in (self.P):
            count = 1
            print(f'Computing Fitness: {count}/{len(self.P)}')
            count+=1
            try:
                Fit.append(total_lines(calc_coverage(p[0], p[1], self.input)))
            except:
                Fit.append(0)
                self.fail_P.append(p)
                print('Fail to compute fitess')
            
        return Fit

    # select m candidates for parents of next-generation inputs
    def select(self, m, Fit, file=None):
        selected_index = np.argpartition(Fit, -m)[-m:]
        P_prime = [self.P[_] for _ in selected_index]
#         print(f'\nselect {selected_index}, of {Fit[selected_index[0]]} and {Fit[selected_index[1]]}')
#         print(P_prime,'\n\n')
        if file!=None:
            file.write(f'{P_prime}, ')
            file.write(f'{[Fit[_] for _ in selected_index]}\n')
    
        return P_prime

    # select 2 parents from the candidates
    def selectParents(self, P_prime):
        x1, x2 = random.sample(list(P_prime), 2)
        return x1, x2

    # return a flatten list of a crossover product of the selected parents
    def crossover(self, x1, x2, r1):
#         x1_factor = np.random.choice(2, size=x1.shape, p=[1-r1, r1])
#         x2_factor = 1 - x1_factor
        
#         x_prime = x1 * x1_factor + x2 * x2_factor
        print('--crossover--')
        return x_prime

    # mutate the crossover product
    def mutate(self, x_prime):
        architecture = x_prime[0][:]
        seedlist = x_prime[1][:]
        
        #add random layer
        aval_layer = []
        for layer in layer_dict.index.tolist():
            if layer not in architecture: aval_layer.append(layer)

        if aval_layer:
            newlayer = random.choice(aval_layer)
            newseed = np.ones(layer_dict.loc[newlayer]['para_num'], dtype=int).tolist()

            insert = int(random.random()*len(architecture))

            architecture.insert(insert, newlayer)
            seedlist.insert(insert, newseed)
        
        #mutate hyperparameters
        mutate_seedlist = []
        for seed in seedlist:
            noise = np.array([_ for _ in np.random.standard_cauchy(len(seed))], dtype=int)
            mutate_seedlist.append((seed + noise).tolist())
#         print('print mutated population: ',  architecture, mutate_seedlist)
        return (architecture, mutate_seedlist)

# %%
def ga_main(model_architecture, seedlist, x, m, n, maxIter, ga=None):
    sstart_time = time.time()
    f = open("Coverage_Log.csv", "a")
    f.write('Iteration, Selected, Fit')
    
    if ga == None:
        print('init GA')
        ga = Cov_GA(model_architecture, seedlist, x)
        ga.initPopulation(n)
        
    else:
        print('Continuing from the previous populations...')
        
    prev_iter = len(ga.fit_hist)
    for i in range(prev_iter, prev_iter + maxIter):
        f.write(f'{i}, ')
        print(f'Running at iteration {i+1}:')
        start_time = time.time()
        Fit = ga.computeFitness()
        ga.fit_hist.append(Fit)
        
        if i < prev_iter + maxIter - 1: # no mutation and crossover in the last iteration
            P_prime = ga.select(m, Fit, f)
            P_pp = []
            P_pp.extend(P_prime)
            while len(P_pp) < n:
                x1, x2 = ga.selectParents(P_prime)
#               x_prime = ga.crossover(x1, x2)
                #crossover
                x_pp = ga.mutate(x1)
                P_pp.append(x_pp)
        ga.P = P_pp
            
        end_time = time.time()
        print('Average fitness value: {}'.format(np.mean(Fit)))
        print('Time taken: {}'.format(end_time - start_time))
        print()
    
    f.close
    print()
    print('Total time taken:', end_time - sstart_time)
    
    return ga

# %%
lastP = [(['SeparableConv2D', 'GaussianNoise', 'GlobalMaxPooling2D', 'Conv2D', 'Flatten', 'SeparableConv1D', 'RepeatVector', 'LeakyReLU', 'Dropout', 'GaussianDropout', 'MaxPooling2D', 'BatchNormalization', 'Conv1D', 'GRU', 'Conv2DTranspose', 'Dense'], [[-5, 10, 3, 29], [-2], [-14], [17, -5, 1, 8], [], [-25, -7, -127, -10], [7], [3], [-18, -1], [-22], [-7, -1], [3, 3], [2, 3, 0, 0], [-1, 6, 64], [225, -7, -10, 72], [38]]), (['SeparableConv2D', 'GaussianNoise', 'GlobalMaxPooling2D', 'Conv2D', 'Flatten', 'SeparableConv1D', 'Conv3DTranspose', 'RepeatVector', 'GaussianDropout', 'ReLU', 'BatchNormalization', 'Conv1D', 'GRU', 'LayerNormalization', 'Conv2DTranspose', 'Dense'], [[20, 9, 3, 31], [1], [-12], [22, 1, -5, 3], [], [97, 2, -127, -14], [1, 1, 5, 0], [-7], [22], [1], [3, -3], [-3, 2, -5, -19], [7, 6, 0], [2, 1, 1], [227, -3, -6, 102], [36]])]
bestP = lastP[1]

a = bestP[0]
sl = bestP[1]

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x = x_test[0]

# %%
a = ['Conv2D', 'Flatten', 'Dense']
sl = [[0,0,0,0], [], [0]]

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x = x_test[0]

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
x = x_test[0]

a= ['Conv2D', 'Dense', 'Flatten']

sl = []
[sl.append(None) for _ in a]

# sl = lastP[0][1]

model = buildModelByArtchitect(a, sl, x.shape)

# %%
ga = Cov_GA(a, sl, x)
ga.initPopulation(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-17b23c4b64ed> in <module>
#       1 ga = Cov_GA(a, sl, x)
# ----> 2 ga.initPopulation(5)
#
# <ipython-input-3-759388639218> in initPopulation(self, n)
#      54             mutate_seedlist = []
#      55             for seed in self.source_seedlist:
# ---> 56                 noise = np.array([_ for _ in np.random.standard_cauchy(len(seed))], dtype=int)
#      57                 mutate_seedlist.append((seed + noise).tolist())
#      58             self.P.append((self.source_architect, mutate_seedlist))
#
# TypeError: object of type 'NoneType' has no len()

# %%
ga_main(a, sl, x, m=2, n=5, maxIter=20)
# Out:
# init GA
# Initializaing population: 1/5
# Initializaing population: 2/5
# Initializaing population: 3/5
# Initializaing population: 4/5
# Running at iteration 1:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Average fitness value: 6351.4
# Time taken: 138.58545923233032
#
# Running at iteration 2:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Average fitness value: 6974.6
# Time taken: 171.45875358581543
#
# Running at iteration 3:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Fail to compute fitess
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Average fitness value: 6163.2
# Time taken: 153.7282998561859
#
# Running at iteration 4:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Fail to compute fitess
# Average fitness value: 6701.2
# Time taken: 149.88199257850647
#
# Running at iteration 5:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Average fitness value: 8473.2
# Time taken: 199.25180768966675
#
# Running at iteration 6:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Average fitness value: 8608.0
# Time taken: 166.1246259212494
#
# Running at iteration 7:
# Computing Fitness: 1/5
# Computing Fitness: 1/5
# Computing Fitness: 1/5

# %%
ga.P
# Out:
# [(['AveragePooling2D',
#    'Conv2D',
#    'LocallyConnected2D',
#    'Conv1D',
#    'LSTM',
#    'DepthwiseConv2D',
#    'Dense',
#    'SeparableConv2D',
#    'SpatialDropout1D',
#    'GlobalAveragePooling1D',
#    'SeparableConv1D',
#    'GlobalAveragePooling2D',
#    'GRU',
#    'Activation',
#    'GlobalMaxPooling1D',
#    'BatchNormalization',
#    'AveragePooling1D',
#    'Flatten'],
#   [[6, 3],
#    [-1, 19, -3, 19],
#    [-7, -19, -9],
#    [-29, 1, 0, -1],
#    [2, 4, -8, -3, 2, 36, 52, 11],
#    [1, 11, 8],
#    [9],
#    [0, 23, 7, 0],
#    [-305],
#    [175],
#    [3, 0, 6, -14],
#    [12],
#    [1, 30, 5],
#    [-3],
#    [3],
#    [-46, -2],
#    [56, 0],
#    []]),
#  (['Conv2D',
#    'LocallyConnected2D',
#    'LSTM',
#    'DepthwiseConv2D',
#    'Dense',
#    'SimpleRNN',
#    'SeparableConv2D',
#    'SpatialDropout1D',
#    'GlobalAveragePooling1D',
#    'SeparableConv1D',
#    'GlobalAveragePooling2D',
#    'GRU',
#    'Activation',
#    'GaussianDropout',
#    'GlobalMaxPooling1D',
#    'BatchNormalization',
#    'AveragePooling1D',
#    'Flatten'],
#   [[106, 18, -4, 20],
#    [21, -39, -5],
#    [-7, 14, -7, 0, 2, 32, 52, 13],
#    [2, 3, 5],
#    [-5],
#    [1, 2, 1, -1, 1, 1],
#    [-3, 5, -21, 1],
#    [-348],
#    [174],
#    [4, 5, 9, -15],
#    [6],
#    [3, 54, -2],
#    [11],
#    [32],
#    [-36],
#    [-46, -2],
#    [49, 3],
#    []]),
#  (['Conv2D',
#    'LocallyConnected2D',
#    'LSTM',
#    'DepthwiseConv2D',
#    'Dense',
#    'SimpleRNN',
#    'SeparableConv2D',
#    'GlobalAveragePooling3D',
#    'SpatialDropout1D',
#    'GlobalAveragePooling1D',
#    'SeparableConv1D',
#    'GlobalAveragePooling2D',
#    'GRU',
#    'Activation',
#    'GaussianDropout',
#    'GlobalMaxPooling1D',
#    'BatchNormalization',
#    'AveragePooling1D',
#    'Flatten'],
#   [[106, 13, -4, 55],
#    [22, -38, -2],
#    [-7, 14, -7, 0, 0, 32, 52, 15],
#    [2, 3, 5],
#    [-6],
#    [-3, 4, 1, -1, -1, 19],
#    [-4, 5, -21, 6],
#    [1],
#    [-348],
#    [174],
#    [4, 5, 9, -15],
#    [21],
#    [2, 62, -1],
#    [10],
#    [32],
#    [-36],
#    [-46, -3],
#    [49, 3],
#    []]),
#  (['Conv2D',
#    'LocallyConnected2D',
#    'LSTM',
#    'DepthwiseConv2D',
#    'Dense',
#    'SimpleRNN',
#    'SeparableConv2D',
#    'SpatialDropout1D',
#    'GlobalAveragePooling1D',
#    'SeparableConv1D',
#    'GlobalAveragePooling2D',
#    'GRU',
#    'Activation',
#    'GaussianDropout',
#    'ReLU',
#    'GlobalMaxPooling1D',
#    'BatchNormalization',
#    'AveragePooling1D',
#    'Flatten'],
#   [[108, 18, -4, 20],
#    [21, -41, -5],
#    [-7, 14, -10, -11, 2, 32, 53, 15],
#    [2, 2, 32],
#    [-5],
#    [2, 24, 1, 1, 1, 1],
#    [-3, 5, -23, 2],
#    [-349],
#    [174],
#    [11, 4, 9, -15],
#    [9],
#    [3, 51, -2],
#    [17],
#    [32],
#    [2],
#    [-32],
#    [-46, -3],
#    [50, 3],
#    []]),
#  (['AveragePooling2D',
#    'Conv2D',
#    'LocallyConnected2D',
#    'Conv1D',
#    'LSTM',
#    'DepthwiseConv2D',
#    'Dense',
#    'SeparableConv2D',
#    'SpatialDropout1D',
#    'GlobalAveragePooling1D',
#    'SeparableConv1D',
#    'GlobalAveragePooling2D',
#    'GRU',
#    'ZeroPadding2D',
#    'Activation',
#    'GlobalMaxPooling1D',
#    'BatchNormalization',
#    'AveragePooling1D',
#    'Flatten'],
#   [[6, 4],
#    [-1, 20, -5, 20],
#    [-7, -41, -12],
#    [-29, -2, -16, -2],
#    [-2, 5, -8, -3, 3, 36, 52, 10],
#    [2, 11, 16],
#    [9],
#    [0, 34, -17, 0],
#    [-304],
#    [175],
#    [15, 0, 5, -23],
#    [17],
#    [1, 43, 6],
#    [1],
#    [-4],
#    [4],
#    [-46, -5],
#    [62, -1],
#    []])]
