# %%
def addDense(name, config = tf.keras.layers.Dense(units=1, input_shape=[1]).get_config(), seed = 1):
    # Adjustable parameters: unit(0-100)
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    return tf.keras.layers.Dense.from_config(config)

def addConv2D(name, config = tf.keras.layers.Conv2D(filters=1, kernel_size=1).get_config(), seed = 1):  #(550 paras)  
    # Adjustable parameters: filters(0-20), kernel_size([(1-20), (1-20)]), strides([(1-5), (1-5)]), padding('valid', 'same'),
    # activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'exponential', 'linear', None)
    # kernel_initializer('Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 'VarianceScaling',
    # 'Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 'he_normal', 'lecun_normal', 'Identity) 
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.Conv2D.from_config(config)
    
def addBatchNorm(name, config = tf.keras.layers.BatchNormalization().get_config(), seed = 1):
    # Adjustable parameter: momentum(0.0-1.0), epsilon(0.0-1.0)
    config["name"] = f'la{name}yer'
    config["momentum"] = 1/5*(seed % 5)
    config["epsilon"] = 1/5*(seed % 5)
    
    return tf.keras.layers.BatchNormalization.from_config(config)
    
    
def addMaxPool(name, config = tf.keras.layers.MaxPooling2D(pool_size=(1,1)).get_config(), seed = 1):
    # Adjustable parameter: pool_size[(1-5), (1-5)], strides([(1-5), (1-5)]), padding('valid', 'same')
    config["name"] = f'la{name}yer'
#     config["pool_size"] = [int(5/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["padding"] = ['valid', 'same'][seed % 2]
    
    return tf.keras.layers.MaxPooling2D.from_config(config)
    

def addDropout(name, config = tf.keras.layers.Dropout(rate=0.1).get_config(), seed = 1):
    # Adjustable parameter: rate(0.0-1.0), seed(1, 2, 3, 4, 5)
    config["name"] = f'la{name}yer'
    config["rate"] = 1/5*(seed % 5)
    config["seed"] = seed % 5
    return tf.keras.layers.Dropout.from_config(config)

def addActivation(name, config = tf.keras.layers.Activation(activation="softmax").get_config(), seed = 1):
    # Adjustable parameter: activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 
    # 'sigmoid', 'hard_sigmoid', 'exponential', 'linear')
    config["name"] = f'la{name}yer'
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 
     'sigmoid', 'hard_sigmoid', 'exponential', 'linear'][seed % 11]
    
    return tf.keras.layers.Activation.from_config(config)

def addZeroPadd(name, config = tf.keras.layers.ZeroPadding2D().get_config(), seed = 1):
    # Adjustable parameter: activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 
    # 'sigmoid', 'hard_sigmoid', 'exponential', 'linear')
    config["name"] = f'la{name}yer'
    config["padding"] =[int(9/5*(seed % 5))+1 for _ in range(2)]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    
    return tf.keras.layers.ZeroPadding2D.from_config(config)

# New
def addAverPool1D(name, config = tf.keras.layers.AveragePooling1D(pool_size=1).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
#     config["pool_size"] = [int(5/5*(seed % 5)) for _ in range(2)]
    config["strides"] = int(5/5*(seed % 5))+1
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]

    return tf.keras.layers.AveragePooling1D.from_config(config)


def addAverPool2D(name, config = tf.keras.layers.AveragePooling2D(pool_size=(1,1)).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
#     config["pool_size"] = [int(5/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]

    return tf.keras.layers.AveragePooling2D.from_config(config)

def addAverPool3D(name, config = tf.keras.layers.AveragePooling3D(pool_size=(1,1,1)).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
#     config["pool_size"] = [int(5/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(3)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]

    return tf.keras.layers.AveragePooling3D.from_config(config)

# def addBidirectional(name, config = tf.keras.layers.Bidirectional().get_config(), seed = 1):
#     # Adjustable parameter: merge_mode{'sum', 'mul', 'concat', 'ave', None}
#     config["name"] = f'la{name}yer'
#     config["merge_mode"] = ['sum', 'mul', 'concat', 'ave', None][seed % 5]

#     return tf.keras.layers.Bidirectional.from_config(config)
#     need attribute layer


def addConv1D(name, config = tf.keras.layers.Conv1D(filters=1, kernel_size=1).get_config(), seed = 1):  #(550 paras)  
    # Adjustable parameters: filters(0-20), kernel_size([(1-20), (1-20)]), strides([(1-5), (1-5)]), padding('valid', 'same'),
    # activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'exponential', 'linear', None)
    # kernel_initializer('Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 'VarianceScaling',
    # 'Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 'he_normal', 'lecun_normal', 'Identity) 
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = int(5/5*(seed % 5))+1
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.Conv1D.from_config(config)

def addConv3D(name, config = tf.keras.layers.Conv3D(filters=1, kernel_size=1).get_config(), seed = 1):  #(550 paras)  
    # Adjustable parameters: filters(0-20), kernel_size([(1-20), (1-20)]), strides([(1-5), (1-5)]), padding('valid', 'same'),
    # activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'exponential', 'linear', None)
    # kernel_initializer('Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 'VarianceScaling',
    # 'Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 'he_normal', 'lecun_normal', 'Identity) 
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(3)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(3)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.Conv3D.from_config(config)

# %%
import tensorflow as tf

def addThresholdedReLU(name, config = tf.keras.layers.ThresholdedReLU().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["theta"] = 1/5*(seed % 5)
    return tf.keras.layers.ThresholdedReLU.from_config(config)

# %%
addThresholdedReLU("test")

# %%
def addLeakyReLU(name, config = tf.keras.layers.LeakyReLU().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["alpha"] = 1/5*(seed % 5)
    return tf.keras.layers.LeakyReLU.from_config(config)

def addLocallyConnected1D(name, config = tf.keras.layers.LocallyConnected1D(filters=1, kernel_size=1).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.LocallyConnected1D.from_config(config)

def addLocallyConnected2D(name, config = tf.keras.layers.LocallyConnected2D(filters=1, kernel_size=1).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.LocallyConnected2D.from_config(config)

def addReLU(name, config = tf.keras.layers.ReLU().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["max_value"] = 1/5*(seed % 5)
#    config["negative_slope"] = 1/5*(seed % 5)
#    config["threshold"] = 1/5*(seed % 5)
    return tf.keras.layers.ReLU.from_config(config)

def addRepeatVector(name, config = tf.keras.layers.RepeatVector(n=2).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["n"] = int(1000/5*(seed % 5))
    return tf.keras.layers.RepeatVector.from_config(config)

def addSeparableConv1D(name, config = tf.keras.layers.SeparableConv1D(filters=1, kernel_size=1).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1]
    config["padding"] = ['valid', 'same', 'causal'][seed % 3]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.SeparableConv1D.from_config(config)

def addSeparableConv2D(name, config = tf.keras.layers.SeparableConv2D(filters=1, kernel_size=1).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.SeparableConv2D.from_config(config)

def addSimpleRNN(name, config = tf.keras.layers.SimpleRNN(units=2).get_config(), seed = 1):
    # Adjustable parameter: dropout(0.0-1.0), recurrant_dropout(0.0-1.0)
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
    config["use_bias"] = [True, False][seed % 2]
    config["dropout"] = 1/5*(seed % 5)
    config["recurrent_dropout"] = 1/5*(seed % 5)
    config["return_sequences"] = [True, False][seed % 2]
    config["return_state"] = [True, False][seed % 2]
#    config["go_backwards"] = [True, False][seed % 2]
    config["stateful"] = [True, False][seed % 2]
#    config["unroll"] = [True, False][seed % 2]

    return tf.keras.layers.SimpleRNN.from_config(config)

def addSimpleRNNCell(name, config = tf.keras.layers.SimpleRNNCell(units=2).get_config(), seed = 1):
    # Adjustable parameter: dropout(0.0-1.0), recurrant_dropout(0.0-1.0)
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
    config["use_bias"] = [True, False][seed % 2]
    config["dropout"] = 1/5*(seed % 5)
    config["recurrent_dropout"] = 1/5*(seed % 5)

    return tf.keras.layers.SimpleRNNCell.from_config(config)

def addSpatialDropout1D(name, config = tf.keras.layers.SpatialDropout1D(rate=2).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["rate"] = int(1000/5*(seed % 5))
    return tf.keras.layers.SpatialDropout1D.from_config(config)

def addSpatialDropout2D(name, config = tf.keras.layers.SpatialDropout2D(rate=2).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["rate"] = int(1000/5*(seed % 5))
    config["data_format"] = ['channels_first','channels_last'][seed % 2]

    return tf.keras.layers.SpatialDropout2D.from_config(config)   

def addSpatialDropout3D(name, config = tf.keras.layers.SpatialDropout3D(rate=2).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["rate"] = int(1000/5*(seed % 5))
    config["data_format"] = ['channels_first','channels_last'][seed % 2]

    return tf.keras.layers.SpatialDropout3D.from_config(config)

def addThresholdedReLU(name, config = tf.keras.layers.ThresholdedReLU().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["theta"] = 1/5*(seed % 5)
    return tf.keras.layers.ThresholdedReLU.from_config(config)

# %%
dir(tf.keras.layers)
# Out:
# ['AbstractRNNCell',
#  'Activation',
#  'ActivityRegularization',
#  'Add',
#  'AdditiveAttention',
#  'AlphaDropout',
#  'Attention',
#  'Average',
#  'AveragePooling1D',
#  'AveragePooling2D',
#  'AveragePooling3D',
#  'AvgPool1D',
#  'AvgPool2D',
#  'AvgPool3D',
#  'BatchNormalization',
#  'Bidirectional',
#  'Concatenate',
#  'Conv1D',
#  'Conv1DTranspose',
#  'Conv2D',
#  'Conv2DTranspose',
#  'Conv3D',
#  'Conv3DTranspose',
#  'ConvLSTM2D',
#  'Convolution1D',
#  'Convolution1DTranspose',
#  'Convolution2D',
#  'Convolution2DTranspose',
#  'Convolution3D',
#  'Convolution3DTranspose',
#  'Cropping1D',
#  'Cropping2D',
#  'Cropping3D',
#  'Dense',
#  'DenseFeatures',
#  'DepthwiseConv2D',
#  'Dot',
#  'Dropout',
#  'ELU',
#  'Embedding',
#  'Flatten',
#  'GRU',
#  'GRUCell',
#  'GaussianDropout',
#  'GaussianNoise',
#  'GlobalAveragePooling1D',
#  'GlobalAveragePooling2D',
#  'GlobalAveragePooling3D',
#  'GlobalAvgPool1D',
#  'GlobalAvgPool2D',
#  'GlobalAvgPool3D',
#  'GlobalMaxPool1D',
#  'GlobalMaxPool2D',
#  'GlobalMaxPool3D',
#  'GlobalMaxPooling1D',
#  'GlobalMaxPooling2D',
#  'GlobalMaxPooling3D',
#  'Input',
#  'InputLayer',
#  'InputSpec',
#  'LSTM',
#  'LSTMCell',
#  'Lambda',
#  'Layer',
#  'LayerNormalization',
#  'LeakyReLU',
#  'LocallyConnected1D',
#  'LocallyConnected2D',
#  'Masking',
#  'MaxPool1D',
#  'MaxPool2D',
#  'MaxPool3D',
#  'MaxPooling1D',
#  'MaxPooling2D',
#  'MaxPooling3D',
#  'Maximum',
#  'Minimum',
#  'Multiply',
#  'PReLU',
#  'Permute',
#  'RNN',
#  'ReLU',
#  'RepeatVector',
#  'Reshape',
#  'SeparableConv1D',
#  'SeparableConv2D',
#  'SeparableConvolution1D',
#  'SeparableConvolution2D',
#  'SimpleRNN',
#  'SimpleRNNCell',
#  'Softmax',
#  'SpatialDropout1D',
#  'SpatialDropout2D',
#  'SpatialDropout3D',
#  'StackedRNNCells',
#  'Subtract',
#  'ThresholdedReLU',
#  'TimeDistributed',
#  'UpSampling1D',
#  'UpSampling2D',
#  'UpSampling3D',
#  'Wrapper',
#  'ZeroPadding1D',
#  'ZeroPadding2D',
#  'ZeroPadding3D',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys',
#  'add',
#  'average',
#  'concatenate',
#  'deserialize',
#  'dot',
#  'experimental',
#  'maximum',
#  'minimum',
#  'multiply',
#  'serialize',
#  'subtract']

# %%
def addConv2DTranspose(name, config = tf.keras.layers.Conv2DTranspose(filters=1, kernel_size=1).get_config(), seed = 1):  #(550 paras)  
    # Adjustable parameters: filters(0-20), kernel_size([(1-20), (1-20)]), strides([(1-5), (1-5)]), padding('valid', 'same'),
    # activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'exponential', 'linear', None)
    # kernel_initializer('Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 'VarianceScaling',
    # 'Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 'he_normal', 'lecun_normal', 'Identity) 
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.Conv2DTranspose.from_config(config)

def addConv3DTranspose(name, config = tf.keras.layers.Conv3DTranspose(filters=1, kernel_size=1).get_config(), seed = 1):  #(550 paras)  
    # Adjustable parameters: filters(0-20), kernel_size([(1-20), (1-20)]), strides([(1-5), (1-5)]), padding('valid', 'same'),
    # activation(‘softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid', 'exponential', 'linear', None)
    # kernel_initializer('Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 'VarianceScaling',
    # 'Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 'he_normal', 'lecun_normal', 'Identity) 
    config["name"] = f'la{name}yer'
    config["filters"] = int(20/5*(seed % 5))+1
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(3)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(3)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]
    
    return tf.keras.layers.Conv3DTranspose.from_config(config)

def addDepthwiseConv2D(name, config = tf.keras.layers.DepthwiseConv2D(kernel_size=1).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
#     config["kernel_size"]= [int(20/5*(seed % 5)) for _ in range(2)]
    config["strides"] = [int(5/5*(seed % 5))+1 for _ in range(2)]
    config["padding"] = ['valid', 'same'][seed % 2]
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]    
    return tf.keras.layers.DepthwiseConv2D.from_config(config)

def addFlatten(name, config = tf.keras.layers.Flatten().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]

    return tf.keras.layers.Flatten.from_config(config)

def addGRU(name, config = tf.keras.layers.GRU(units=2).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
    config["use_bias"] = [True, False][seed % 2]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]

    return tf.keras.layers.GRU.from_config(config)

def addGRUCell(name, config = tf.keras.layers.GRUCell(units=2).get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
    config["use_bias"] = [True, False][seed % 2]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]

    return tf.keras.layers.GRUCell.from_config(config)

def addGaussianDropout(name, config = tf.keras.layers.GaussianDropout(rate=0.1).get_config(), seed = 1):
    # Adjustable parameter: rate(0.0-1.0), seed(1, 2, 3, 4, 5)
    config["name"] = f'la{name}yer'
    config["rate"] = 1/5*(seed % 5)
    config["seed"] = seed % 5
    return tf.keras.layers.GaussianDropout.from_config(config)

def addGaussianNoise(name, config = tf.keras.layers.GaussianNoise(stddev=0.1).get_config(), seed = 1):
    # Adjustable parameter: stddev(0.0-1.0), seed(1, 2, 3, 4, 5)
    config["name"] = f'la{name}yer'
    config["stddev"] = 1/5*(seed % 5)
    config["seed"] = seed % 5
    return tf.keras.layers.GaussianNoise.from_config(config)

def addGloAverPool1D(name, config = tf.keras.layers.GlobalAveragePooling1D().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["keepdims"] = [True, False][seed % 2]

    return tf.keras.layers.GlobalAveragePooling1D.from_config(config)


def addGloAverPool2D(name, config = tf.keras.layers.GlobalAveragePooling2D().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["keepdims"] = [True, False][seed % 2]

    return tf.keras.layers.GlobalAveragePooling2D.from_config(config)

def addGloAverPool3D(name, config = tf.keras.layers.GlobalAveragePooling3D().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["keepdims"] = [True, False][seed % 2]

    return tf.keras.layers.GlobalAveragePooling3D.from_config(config)

def addGloMaxPool1D(name, config = tf.keras.layers.GlobalMaxPool1D().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["keepdims"] = [True, False][seed % 2]

    return tf.keras.layers.GlobalMaxPool1D.from_config(config)


def addGloMaxPool2D(name, config = tf.keras.layers.GlobalMaxPooling2D().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["keepdims"] = [True, False][seed % 2]

    return tf.keras.layers.GlobalMaxPooling2D.from_config(config)

def addGloMaxPool3D(name, config = tf.keras.layers.GlobalMaxPooling3D().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    config["data_format"] = ['channels_first','channels_last'][seed % 2]
    config["keepdims"] = [True, False][seed % 2]

    return tf.keras.layers.GlobalMaxPooling3D.from_config(config)


def addLSTM(name, config = tf.keras.layers.LSTM(units=2).get_config(), seed = 1):
    # Adjustable parameter: dropout(0.0-1.0), recurrant_dropout(0.0-1.0)
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
    config["use_bias"] = [True, False][seed % 2]
    config["dropout"] = 1/5*(seed % 5)
    config["recurrent_dropout"] = 1/5*(seed % 5)
    config["return_sequences"] = [True, False][seed % 2]
    config["return_state"] = [True, False][seed % 2]
    config["go_backwards"] = [True, False][seed % 2]
    config["stateful"] = [True, False][seed % 2]    
    config["time_major"] = [True, False][seed % 2]
    config["unroll"] = [True, False][seed % 2]
#     config["kernel_initializer"] = ['Zeros', 'Ones', 'Constant', 'RandomNormal', 'RandomUniform', 'TruncatedNormal', 
#                                     'VarianceScaling','Orthogonal', 'lecun_uniform', 'glorot_normal', 'glorot_uniform', 
#                                     'he_normal', 'lecun_normal', 'Identity'][seed % 14]

    return tf.keras.layers.LSTM.from_config(config)

def addLSTMCell(name, config = tf.keras.layers.LSTMCell(units=2).get_config(), seed = 1):
    # Adjustable parameter: dropout(0.0-1.0), recurrant_dropout(0.0-1.0)
    config["name"] = f'la{name}yer'
    config["units"] = int(1000/5*(seed % 5))
    config["activation"] = ['softmax', 'elu', 'selu', 'softplus', 'softsign', 'relu', 'tanh', 'sigmoid', 'hard_sigmoid',
                            'exponential', 'linear'][seed % 11]
    config["use_bias"] = [True, False][seed % 2]
    config["dropout"] = 1/5*(seed % 5)
    config["recurrent_dropout"] = 1/5*(seed % 5)

    return tf.keras.layers.LSTMCell.from_config(config)

def addLayerNormal(name, config = tf.keras.layers.LayerNormalization().get_config(), seed = 1):
    config["name"] = f'la{name}yer'
    # config["axis"]
    config["epsilon"] = 1/5*(seed % 5)
    config["center"] = [True, False][seed % 2]
    config["scale"] = [True, False][seed % 2]
    return tf.keras.layers.LayerNormalization.from_config(config)
